# %% [markdown]
# # Experiment: AIGC Report Analysis
#
# 该 Notebook 用于复现实验报告中的核心图表与表格，包括训练曲线、阈值扫描、混淆矩阵、PR 曲线以及 V8/V9/V10 对比表。

# %% [markdown]
# ## Data Sources
#
# - `checkpoints/best.pth`：最终 V10 `base_only` 模型及其训练历史
# - `tmp/report_generation/photos_predictions_raw.csv`：当前最终模型对 `photos_test` 的真实推理结果
# - `docs/reference/v9_reference_report.json`：V9 基线结果
# - `photos_test/labels.csv`：19 张评估图片真值标签

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from scripts.generate_report_artifacts import generate_report_artifacts

summary = generate_report_artifacts(PROJECT_ROOT)
summary

# %%
import pandas as pd

version_df = pd.read_csv(PROJECT_ROOT / "tmp/report_generation/version_comparison.csv")
threshold_df = pd.read_csv(PROJECT_ROOT / "tmp/report_generation/threshold_profiles.csv")
display(version_df)
display(threshold_df)

# %%
from IPython.display import Image, display

for name in [
    "training_curves.png",
    "threshold_sweep.png",
    "confusion_matrix_recall_first.png",
    "precision_recall_curve.png",
]:
    display(Image(filename=str(PROJECT_ROOT / "figures" / name)))
